# %% [markdown]
# ## Best Model : Polynomial Regression (Based on CV Score)
# - CV Score:  0.9114985160662464
# - Training Score: 0.9114985160662464
# - Test Score: 0.8755530241459522
#
#
# ## Linear Regression
# - CV score:  0.9114426745730106
# - Training score: 0.9102975951657948
# - Test Score: 0.8746968378820517
#
#
# ## Polynomial Regression
# - - Models used with hyperparameters : 'degree':(1,2)
# - best params {'degree': 1}
# - CV Score:  0.9114985160662464
# - Training Score: 0.9114985160662464
# - Test Score: 0.8755530241459522
#
#
# ## SGD Regressor
# - Models used with hyperparameters : {learning_rate':['invscaling','adaptive'],'penalty':['l2', 'l1','elasticnet'],
#              'alpha':[0.0001,0.0005,0.001],
#              'l1_ratio':[0.15,0.20,0.40,0.50,0.60],
#              'tol':[1e-4,1e-3]
# - Best Model parameters: {'alpha': 0.0005, 'l1_ratio': 0.5, 'learning_rate': 'adaptive', 'penalty': 'elasticnet', 'tol': 0.001}
# - CV Score:  0.891594730863832
# - Training Score: 0.891594730863832
# - Test Score: 0.8308356404127091
#
# ## Ridge Regressor
#  - Models used with hyperparameters :'alpha':[0.001, 0.01,0.05, 0.1, 0.25,0.5,1, 10,100,150]
#  - Best Model parameters: 'alpha': 100
#  - CV Score:  0.8841976405377137
#  - Training Score: 0.9103295889443214
#  - Test Score: 0.8731529205790174
#
#
# ## Lasso Regressor
#  - Models used with hyperparameters :'alpha':[0.001, 0.01,0.05, 0.1, 0.25,0.5,1, 10,100,150]
#  - Best Model parameters: 'alpha': 150
#  - CV Score:  0.8856334588062339
#  - Training Score: 0.9110302586543852
#  - Test Score: 0.87806158664072
#
# ## KNN Regressor
#  - Models used with hyperparameters: 'weights':['uniform','distance'],'leaf_size': [5,10,20,30],'n_neighbors': [5,10,15],'p':[1,2,3]}
#  - Best Model parameters: 'leaf_size': 5, 'n_neighbors': 5, 'p': 1, 'weights': 'distance'
#   - CV Score:  0.8354252209693938
#  - Training Score: 0.9999955968722103
#  - Test Score: 0.7898527883440282
#
# ## Decision Tree Regresser
#  - Models used with hyperparameters:    'criterion':['mse','friedman_mse','mae'],'splitter':['random','best'],
#     'max_depth':[20,30],'min_samples_split':[4,8,12,16],'min_samples_leaf' :[2,4,8],'max_features':['auto','sqrt']
#  - Best Model parameters: {criterion': 'mse', 'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 12, 'splitter': 'random'}
#  - CV Score:  0.7980363024025918
#  - Training Score: 0.8771368435976774
#  - Test Score: 0.8033735005070397
#
# ## SVM Regressor
#  - Models used with hyperparameters: kernel':['linear','poly','rbf','sigmoid'],'degree':[3,4,5],'gamma':['auto','scale'],'coef0':[2.0,4.0,10.0,15.0]
#  - Best Model parameters: {'coef0': 10.0, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
#  - CV Score:  0.9004499345276106
#  - Training Score: 0.9534721185647854
#  - Test Score: 0.8741830276841772
#
#
# ## Multiple Models with One GridSearch
#
#  - Models used with hyperparameters:{ 'regressor' :[LinearRegression(), Ridge() , Lasso()]}
#  - Best Model parameters: 'regressor': Lasso(alpha=200, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'alpha': 200}
# - CV Score:  0.83
# - Train Score: 0.981937071382834
# - Test Score: 0.8740776530267179
#
#
# ## Bagging Using Best Model (Polynomial regression)
#
# - CV Score:  -1.7984961372332154e+17
# - best params {'base_estimator__poly__degree': 2, 'max_samples': 0.8, 'n_estimators': 20}
#
# ## Bagging Using Decision Tree
#
# - CV Score:  0.8714664281170718
# - best params {'base_estimator__max_depth': 20, 'base_estimator__max_features': 'auto', 'base_estimator__min_samples_leaf': 2, 'base_estimator__min_samples_split': 4, 'base_estimator__splitter': 'random', 'max_samples': 0.8, 'n_estimators': 40}
#
# ## Pasting Using Best Model (Polynomial regression)
#
# - CV Score:  -0.018930924946367656
# - best params {'base_estimator__poly__degree': 1, 'max_samples': 1, 'n_estimators': 20}
#
# ## Pasting Using Decision Tree
#
# - CV Score:  0.8775043727754538
# - best params {'base_estimator__criterion': 'mse', 'base_estimator__max_depth': 20, 'base_estimator__max_features': 'auto', 'base_estimator__min_samples_leaf': 2, 'base_estimator__min_samples_split': 4, 'base_estimator__splitter': 'random', 'max_samples': 0.8, 'n_estimators': 40}
#
# ## 	Random Forest
#
# - CV Score:  0.8680854208640751
# - •	best params {'max_depth': 30, 'max_samples': 0.7, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 40}
#
# ## 	Ada Boost (with decision tree)
#
# - CV Score:  0.8247415104118545
# - best params {'base_estimator__max_depth': 5, 'base_estimator__max_leaf_nodes': 9, 'base_estimator__min_impurity_decrease': 0.05, 'base_estimator__min_samples_leaf': 10, 'learning_rate': 2, 'n_estimators': 40}
#
# ## Gradient Boost
#
# - CV Score:  0.8779305773463723
# - best params {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 100}
#
# ## 	Extra-Trees
#
# - CV Score:  0.8714797938251614
# - best params {'max_depth': 10, 'max_features': 'auto', 'n_estimators': 50}
#
# ## 	XGBoost
#
# - CV Score:  0.8763193906415836
# - best params {'learning_rate': 0.5, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 40, 'subsample': 1}
#
# ## Voting Regressor to combine results of top 5 models
#
# - Test Score 0.8833649271587256
#
# ## Voting Regressor to combine results of  models with least correlation
#
# - Test Score 0.8363833252204408
#
# ## Stacking Regressor to combine results of top 5 models
# - Taking too long to Converge
#
# ## Stacking Regressor to combine results of  models with least correlation

# %% [markdown]
# ## Data PreProcessing

# %%
from math import sqrt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

pd.pandas.set_option('display.max_columns', None)
# %matplotlib inline

# %% [markdown]
# ### Load Datasets

# %%
# load dataset
# your code here
data = pd.read_csv('/Users/tapas/Downloads/Oil/houseprice.csv')

# %% [markdown]
# ### Types of variables

# %%
# we have an Id variable, that we should not use for predictions:

print('Number of House Id labels: ', len(data.Id.unique()))
print('Number of Houses in the Dataset: ', len(data))
# Out:
# Number of House Id labels:  1460
# Number of Houses in the Dataset:  1460

# %% [markdown]
# #### Find categorical variables

# %%
# find categorical variables- hint data type = 'O'

categorical = [var for var in data.columns if data[var].dtype=='O']

print(f'There are {len(categorical)} categorical variables')
# Out:
# There are 43 categorical variables

# %% [markdown]
# #### Find temporal variables

# %%
# make a list of the numerical variables first= Hint data type != O
numerical = [var for var in data.columns if data[var].dtype!='O']

# list of variables that contain year information= Hint variable namme has Yr or 
year_vars = [var for var in numerical if 'Yr' in var or 'Year' in var]

year_vars
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %% [markdown]
# #### Find discrete variables
#
# To identify discrete variables- numerical variables with less than 20 unique values

# %%
# let's visualise the values of the discrete variables
discrete = [var for var in numerical if len(data[var].unique()) < 20 and var not in year_vars]

print(f'There are {len(discrete)} discrete variables')
# Out:
# There are 14 discrete variables

# %% [markdown]
# #### Continuous variables

# %%
# find continuous variables- hint numerical variables not in discrete and  year_years 
# Also remove the Id variable and the target variable SalePrice
# which are both also numerical

continuous = [var for var in numerical if var not in discrete and var not in [
    'Id', 'SalePrice'] and var not in year_vars]

print('There are {} numerical and continuous variables'.format(len(numerical)))
# Out:
# There are 38 numerical and continuous variables

# %% [markdown]
# ### Separate train and test set

# %%
# Let's separate into train and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data.drop(['Id', 'SalePrice'], axis=1),
                                                    data['SalePrice'],
                                                    test_size=0.1,
                                                    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((1314, 79), (146, 79))

# %% [markdown]
# **Now we will move on and engineer the features of this dataset. The most important part for this course.**

# %% [markdown]
# ### Craete New Variables
#
# Replace 'YearBuilt', 'YearRemodAdd', 'GarageYrBlt  with time elapsed since YrSold
# So YearBuilt = YrSold-YearBuilt.
#
# Similarly transform 'YearRemodAdd', 'GarageYrBlt.
# After making transformation drop YrSold

# %%
# function to calculate elapsed time

def elapsed_years(df, var):
    # capture difference between year variable and
    # year the house was sold
    
    df[var] = df['YrSold'] - df[var]
    return df

# %%
for var in ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt']:
    X_train = elapsed_years(X_train, var)
    X_test = elapsed_years(X_test, var)

# %%
# drop YrSold
X_train.drop('YrSold', axis=1, inplace=True)
X_test.drop('YrSold', axis=1, inplace=True)

# %%
year_vars.remove('YrSold')

# %%
# capture the column names for use later in the notebook
final_columns = X_train.columns
final_columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %% [markdown]
# ### Feature Engineering Pipeline

# %%
# I will treat discrete variables as if they were categorical
# to treat discrete as categorical using Feature-engine
# we need to re-cast them as object

X_train[discrete] = X_train[discrete].astype('O')
X_test[discrete] = X_test[discrete].astype('O')

# %%
# import relevant modules for feature engineering
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from feature_engine import missing_data_imputers as mdi
from feature_engine import categorical_encoders as ce
from feature_engine.variable_transformers import YeoJohnsonTransformer
from sklearn.preprocessing import StandardScaler
from feature_engine.discretisers import DecisionTreeDiscretiser

# %%
house_preprocess = Pipeline([
    
    # missing data imputation 
    ('missing_ind', mdi.AddNaNBinaryImputer(
        variables=['LotFrontage', 'MasVnrArea',  'GarageYrBlt'])),
    ('imputer_num', mdi.MeanMedianImputer(imputation_method='mean',
                                          variables=['LotFrontage', 'MasVnrArea',  'GarageYrBlt'])),
    ('imputer_cat', mdi.CategoricalVariableImputer(variables=categorical)),

    # categorical encoding 
     ('rare_label_enc', ce.RareLabelCategoricalEncoder(
         tol=0.01,n_categories=6, variables=categorical+discrete)),
    ('categorical_enc', ce.MeanCategoricalEncoder(variables = categorical + discrete)),
     
    # Transforming Numerical Variables
    ('yjt', YeoJohnsonTransformer(variables = ['LotFrontage','MasVnrArea', 'GarageYrBlt'])),

    
    # discretisation and encoding
    ('treeDisc',  DecisionTreeDiscretiser(cv=2, scoring='neg_mean_squared_error',
                                   regression=True,
                                   param_grid={'max_depth': [1,2,3,4,5,6]})),

    # feature Scaling
    ('scaler', StandardScaler()),
    
    

])

# %%
house_preprocess.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('missing_ind',
#                  AddNaNBinaryImputer(variables=['LotFrontage', 'MasVnrArea',
#                                                 'GarageYrBlt'])),
#                 ('imputer_num',
#                  MeanMedianImputer(imputation_method='mean',
#                                    variables=['LotFrontage', 'MasVnrArea',
#                                               'GarageYrBlt'])),
#                 ('imputer_cat',
#                  CategoricalVariableImputer(variables=['MSZoning', 'Street',
#                                                        'Alley', 'LotShape',
#                                                        'LandContour',
#                                                        'Utilities', '...
#                                                     'Utilities', 'LotConfig',
#                                                     'LandSlope', 'Neighborhood',
#                                                     'Condition1', 'Condition2',
#                                                     'BldgType', 'HouseStyle',
#                                                     'OverallQual',
#                                                     'OverallCond', 'YearBuilt',
#                                                     'YearRemodAdd', 'RoofStyle',
#                                                     'RoofMatl', 'Exterior1st',
#                                                     'Exterior2nd', 'MasVnrType',
#                                                     'MasVnrArea', 'ExterQual',
#                                                     'ExterCond', 'Foundation',
#                                                     'BsmtQual', ...])),
#                 ('scaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True))],
#          verbose=False)

# %%
# Apply Transformations
X_train=house_preprocess.transform(X_train)
X_test=house_preprocess.transform(X_test)

# %% [markdown]
# ## <span class="mark">DO NOT CHANGE STEPS BEFORE THIS POINT</span>

# %% [markdown]
# ## Regression Models- Tune different models one by one

# %%
# Train a linear regression model, report the coefficients and model performance 

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error,r2_score

lr = LinearRegression()

lr_grid = GridSearchCV(lr,)
lr_grid.fit(X_train, y_train)
cv_scores = cross_val_score(lr, X_train, y_train)

# Mean Cross validation Score
print("CV score: {}".format((cv_scores)))
print("CV score: ",lr.score(X_train, y_train))

# Print Co-efficients
print("lr.coef_:", lr.coef_)
print("lr.intercept_:", lr.intercept_)

# Check test data set performance

X_train_preds = lr.predict(X_train)
X_test_preds = lr.predict(X_test)

print("Training score",r2_score(y_train,X_train_preds))
print("LR Performance Test: ", lr.score(X_train,y_train))
# Out:
# CV score: [ 8.68312903e-01 -6.26561684e+21  8.76203279e-01  8.98626806e-01
#   8.92290590e-01]
# CV score:  0.9114426745730106
# lr.coef_: [ 8.85927525e+02  9.63821950e+02  1.55093914e+03  2.38123720e+03
#   1.54867121e+03  3.94643841e+02  5.73339946e+02  1.32077662e+03
#   1.55946597e+03  2.25919167e+03  1.27504991e+03  1.12929618e+04
#   1.31777294e+03  2.04524613e+03  1.21008674e+03 -9.02846098e+02
#   1.58511847e+04 -9.82124059e+01 -5.41455300e+03  3.94119726e+03
#   3.73336495e+02 -1.17351708e+03  3.44591704e+03 -2.45906679e+03
#  -8.92244713e+02  2.64169300e+02  2.55034152e+03  5.77675879e+02
#   1.02547905e+01  2.43524833e+03  5.95239944e+02  3.56353271e+03
#   1.33859388e+03  5.57728195e+03 -1.43383745e+03  2.11644961e+03
#  -2.80153401e+02  7.89568089e+03  2.44320365e+02  1.63894561e+03
#   1.03758613e+03 -7.92545735e+02  1.21578274e+04  1.11657512e+04
#   4.20710717e+03  5.60685225e+03  2.72048329e+03 -1.21950180e+03
#   4.38283844e+03  5.39795630e+03  5.97516292e+02  2.94689148e+03
#   3.71875504e+03  3.03060751e+03  3.03991793e+03  6.48653394e+02
#   1.78422356e+03 -2.19543947e+03 -2.43854577e+03 -1.18750138e+03
#   4.31765061e+03  2.48635231e+02  2.50813698e+03  2.33631624e+02
#   7.36798066e+01  1.44837613e+03  1.54513968e+03 -1.69712829e+00
#   2.26100996e+03  2.67782301e+03 -1.45711262e+17  1.45711262e+17
#  -3.01498819e+02 -2.05592005e+03  7.45807652e+02 -1.61204738e+02
#  -1.31813584e+03  5.57575260e+03 -1.47800289e+02  2.60314741e+02
#  -1.52950257e+02]
# lr.intercept_: 181040.6240487064
# Training score 0.9114426745730106
# LR Performance Test:  0.9114426745730106

# %%
# Train a linear regression model, report the coefficients and model performance 

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error,r2_score

lr = LinearRegression()
lr_params = {}
lr_grid = GridSearchCV(lr,lr_params,cv=10)

lr_grid.fit(X_train, y_train)
cv_scores = cross_val_score(lr_grid, X_train, y_train)

# Mean Cross validation Score
print("CV score: {}".format((cv_scores)))
print("CV score: ",lr_grid.score(X_train, y_train))



# Check test data set performance

X_train_preds = lr_grid.predict(X_train)
X_test_preds = lr_grid.predict(X_test)

print("Training score",r2_score(y_train,X_train_preds))
print("LR Performance Test: ", lr_grid.score(X_train,y_train))
# Out:
# CV score: [ 8.68312903e-01 -6.26561684e+21  8.76203279e-01  8.98626806e-01
#   8.92290590e-01]
# CV score:  0.9114426745730106
# Training score 0.9114426745730106
# LR Performance Test:  0.9114426745730106

# %% [markdown]
# #  Linear Regression with Polynomial Features

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler

from sklearn.linear_model import LinearRegression
from math import sqrt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import GridSearchCV


reg_poly_pipe = Pipeline([
    ('Poly',PolynomialFeatures()),
    ('lreg',LinearRegression())
])

reg_poly_params = {'Poly__degree':range(1,2)}
reg_poly_grid = GridSearchCV(reg_poly_pipe,reg_poly_params,cv=5, n_jobs=-1,return_train_score = True)

reg_poly_grid.fit(X_train,y_train)

X_train_preds = reg_poly_grid.predict(X_train)
X_test_preds = reg_poly_grid.predict(X_test)

print('Co-efficients',dir(reg_poly_pipe.named_steps['lreg']))
#print('Intercept ',reg_poly_pipe.named_steps['lreg'].intercept_)
print('best params',reg_poly_grid.best_params_)


print('CV Score: ',reg_poly_grid.best_score_)
#
print('CV Score: ',reg_poly_grid.score(X_train,y_train))
#Training score

print('train rmse',sqrt(mean_squared_error(y_train,X_train_preds)))
print("train r2: ", r2_score(y_train,X_train_preds))

print('test rmse',sqrt(mean_squared_error(y_test,X_test_preds)))
print("Test Score/r2: ", r2_score(y_test,X_test_preds))
# Out:
# Co-efficients ['__abstractmethods__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_decision_function', '_estimator_type', '_get_param_names', '_get_tags', '_more_tags', '_preprocess_data', '_set_intercept', 'copy_X', 'fit', 'fit_intercept', 'get_params', 'n_jobs', 'normalize', 'predict', 'score', 'set_params']
# best params {'Poly__degree': 1}
# CV Score:  -2.168230286496948e+20
# CV Score:  0.9114985160662464
# train rmse 23507.198610424522
# train r2:  0.9114985160662464
# test rmse 29244.041532318097
# Test Score/r2:  0.8755530241459522

# %% [markdown]
# ## Why are both CV Scores different ^

# %% [markdown]
# # SGD Regressor

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error,r2_score
from math import sqrt
from sklearn.model_selection import GridSearchCV

reg_sgd_pipe = Pipeline([
    ('scaler',MinMaxScaler()),
    ('sgd_reg',SGDRegressor(max_iter=1000,verbose=11,early_stopping=True,validation_fraction=0.2))
])

param_sgd = {'sgd_reg__learning_rate':['invscaling','adaptive'],
            'sgd_reg__penalty':['l2', 'l1', 'elasticnet'],
             'sgd_reg__alpha':[0.0001,0.0005,0.001],
             'sgd_reg__l1_ratio':[0.15,0.20,0.40,0.50,0.60],
             'sgd_reg__tol':[1e-4,1e-3]
            }
grid_sgd = GridSearchCV(reg_sgd_pipe,param_sgd,cv=5,n_jobs=-1,return_train_score=True)

grid_sgd.fit(X_train,y_train)

X_train_preds = grid_sgd.predict(X_train)
X_test_preds = grid_sgd.predict(X_test)



scores = cross_val_score(grid_sgd, X_train, y_train)
print("Cross-validation scores: {}".format(scores))

print("CV Score",grid_sgd.score(X_train, y_train)) # Training score
print("Mean CV Score :",grid_sgd.best_score_) # CV Score


print('train rmse',sqrt(mean_squared_error(y_train,X_train_preds)))
print("train r2: ", r2_score(y_train,X_train_preds))

print('test rmse',sqrt(mean_squared_error(y_test,X_test_preds)))
print("test r2: ", r2_score(y_test,X_test_preds))

print('best partams', grid_sgd.best_params_)


'''
Cross-validation scores: [0.85629649 0.85130738 0.89215648 0.87668958 0.90063551]
CV Score 0.891594730863832
Mean CV Score : 0.880125237950295
train rmse 26016.615364442063
train r2:  0.891594730863832
test rmse 34095.703270003876
test r2:  0.8308356404127091
best partams {'sgd_reg__alpha': 0.0005, 'sgd_reg__l1_ratio': 0.5, 'sgd_reg__learning_rate': 'adaptive', 'sgd_reg__penalty': 'elasticnet', 'sgd_reg__tol': 0.001}
'''
# Out:
# -- Epoch 1
# Norm: 90839.84, NNZs: 81, Bias: -24.233635, T: 1051, Avg. loss: 724039568.015431
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 105305.59, NNZs: 81, Bias: -839.150956, T: 2102, Avg. loss: 451708307.253731
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 114796.16, NNZs: 81, Bias: -505.956105, T: 3153, Avg. loss: 398788512.269275
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 122246.81, NNZs: 81, Bias: -2781.616127, T: 4204, Avg. loss: 380198013.953986
# Total training time: 0.01 seconds.
# -- Epoch 5
# Norm: 127968.23, NNZs: 81, Bias: -3646.890090, T: 5255, Avg. loss: 371158612.788520
# Total training time: 0.01 seconds.
# -- Epoch 6
# Norm: 132909.61, NNZs: 81, Bias: -4679.936798, T: 6306, Avg. loss: 351105791.580742
# Total training time: 0.01 seconds.
# -- Epoch 7
# Norm: 135840.36, NNZs: 81, Bias: -5053.769635, T: 7357, Avg. loss: 295797307.111805
# Total training time: 0.01 seconds.
# -- Epoch 8
# Norm: 136076.30, NNZs: 81, Bias: -5830.899904, T: 8408, Avg. loss: 292561019.872215
# Total training time: 0.01 seconds.
# -- Epoch 9
# Norm: 137162.47, NNZs: 81, Bias: -6031.270744, T: 9459, Avg. loss: 289218566.748043
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 139346.27, NNZs: 81, Bias: -6105.596687, T: 10510, Avg. loss: 290469694.975755
# Total training time: 0.02 seconds.
# -- Epoch 11
# Norm: 140103.21, NNZs: 81, Bias: -6200.171341, T: 11561, Avg. loss: 285521113.935321
# Total training time: 0.02 seconds.
# -- Epoch 12
# Norm: 140276.17, NNZs: 81, Bias: -6211.574546, T: 12612, Avg. loss: 276927439.880787
# Total training time: 0.02 seconds.
# -- Epoch 13
# Norm: 140381.61, NNZs: 81, Bias: -6302.481934, T: 13663, Avg. loss: 276691398.835062
# Total training time: 0.02 seconds.
# -- Epoch 14
# Norm: 140507.72, NNZs: 81, Bias: -6352.300071, T: 14714, Avg. loss: 275706032.556620
# Total training time: 0.02 seconds.
# -- Epoch 15
# Norm: 140799.01, NNZs: 81, Bias: -6340.211901, T: 15765, Avg. loss: 274864341.579026
# Total training time: 0.02 seconds.
# -- Epoch 16
# Norm: 141011.44, NNZs: 81, Bias: -6357.468753, T: 16816, Avg. loss: 276143810.422919
# Total training time: 0.03 seconds.
# -- Epoch 17
# Norm: 141092.95, NNZs: 81, Bias: -6331.212414, T: 17867, Avg. loss: 272884296.849502
# Total training time: 0.03 seconds.
# -- Epoch 18
# Norm:
# Total training time: 0.04 seconds.
# -- Epoch 30
# Norm: 132307.81, NNZs: 81, Bias: -4655.474793, T: 25230, Avg. loss: 283443521.169629
# Total training time: 0.05 seconds.
# -- Epoch 31
# Norm: 132309.31, NNZs: 81, Bias: -4655.558631, T: 26071, Avg. loss: 283441604.785414
# Total training time: 0.05 seconds.
# -- Epoch 32
# Norm: 132309.58, NNZs: 81, Bias: -4655.594069, T: 26912, Avg. loss: 283410804.072295
# Total training time: 0.05 seconds.
# -- Epoch 33
# Norm: 132309.85, NNZs: 81, Bias: -4655.625798, T: 27753, Avg. loss: 283410500.727878
# Total training time: 0.05 seconds.
# -- Epoch 34
# Norm: 132310.13, NNZs: 81, Bias: -4655.658517, T: 28594, Avg. loss: 283410222.262740
# Total training time: 0.05 seconds.
# -- Epoch 35
# Norm: 132310.40, NNZs: 81, Bias: -4655.693449, T: 29435, Avg. loss: 283409940.226276
# Total training time: 0.05 seconds.
# -- Epoch 36
# Norm: 132310.66, NNZs: 81, Bias: -4655.730139, T: 30276, Avg. loss: 283409649.516581
# Total training time: 0.05 seconds.
# Convergence after 36 epochs took 0.06 seconds
# Cross-validation scores: [0.85975911 0.84926394 0.89024669 0.86706398 0.89147732]
# CV Score 0.8953500700405748
# Mean CV Score : 0.8803640652744067
# train rmse 25562.014172639414
# train r2:  0.8953500700405748
# test rmse 33491.47627374024
# test r2:  0.8367782063881346
# best partams {'sgd_reg__alpha': 0.0005, 'sgd_reg__l1_ratio': 0.2, 'sgd_reg__learning_rate': 'adaptive', 'sgd_reg__penalty': 'elasticnet', 'sgd_reg__tol': 0.001}
# "\nCross-validation scores: [0.85629649 0.85130738 0.89215648 0.87668958 0.90063551]\nCV Score 0.891594730863832\nMean CV Score : 0.880125237950295\ntrain rmse 26016.615364442063\ntrain r2:  0.891594730863832\ntest rmse 34095.703270003876\ntest r2:  0.8308356404127091\nbest partams {'sgd_reg__alpha': 0.0005, 'sgd_reg__l1_ratio': 0.5, 'sgd_reg__learning_rate': 'adaptive', 'sgd_reg__penalty': 'elasticnet', 'sgd_reg__tol': 0.001}\n"

# %% [markdown]
# ## Are CV scores different because they choose different train test sets ^

# %%
# Train a Ridge regression model, report the coefficients, the best parameters, and model performance 
'''
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
ridge = Ridge()

#define a list of parameters
param_ridge = {'alpha':[0.001, 0.01, 0.1, 1, 10, 100] }

grid_ridge = GridSearchCV(ridge, param_ridge, cv=5, return_train_score = True)
grid_ridge.fit(X_train, y_train)

# Mean Cross Validation Score
print("Best Mean Cross-validation score: {:.2f}".format(grid_ridge.best_score_))

print()

#find best parameters
print('Ridge parameters: ', grid_ridge.best_params_)

# print co-eff

print("Ridge.coef_:", grid_ridge.best_estimator_.coef_)
print("Ridge.intercept_:", grid_ridge.best_estimator_.intercept_)

# Check test data set performance

print("Ridge Test Performance: ", grid_ridge.score(X_test,y_test))
'''
# Out:
# Best Mean Cross-validation score: 0.88
#
# Ridge parameters:  {'alpha': 100}
# Ridge.coef_: [ 6.21659729e+02  1.17460178e+03  1.42941553e+03  2.64606835e+03
#   1.51146267e+03  2.62791603e+02  6.67979067e+02  1.18774714e+03
#   1.42260925e+03  2.24214684e+03  1.25368077e+03  9.92739531e+03
#   1.23361742e+03  1.99010230e+03  1.20327177e+03 -6.63081364e+02
#   1.30900812e+04 -4.66276510e+02 -2.83583594e+03  3.23156417e+03
#   6.84148916e+02 -6.10003713e+02  1.78250368e+03 -1.24106895e+03
#  -8.16647095e+02  8.17430994e+02  3.38262729e+03  6.89414122e+02
#  -2.93079656e+02  2.71590898e+03  4.54540556e+02  3.45654634e+03
#   1.37124639e+03  5.85727188e+03 -1.21460614e+03  1.83762570e+03
#  -2.50335442e+02  7.78490680e+03  1.59374113e+02  1.42274787e+03
#   1.23479897e+03 -5.43667577e+02  1.07696364e+04  1.01767254e+04
#   3.73457884e+03  6.25609926e+03  2.54341163e+03 -1.10107201e+03
#   3.81888633e+03  4.50746959e+03  8.23531957e+02  2.86618489e+03
#   4.19642055e+03  3.72923474e+03  2.86150257e+03  1.16162981e+03
#   1.86272306e+03 -1.46071138e+03 -1.49365951e+03 -7.89046316e+02
#   3.51419158e+03  1.50381127e+03  1.65614085e+03  5.11566556e+02
#   3.73952853e+01  1.30344611e+03  1.57916552e+03 -7.37193962e+01
#   2.06813040e+03  2.51850021e+03 -6.51713348e+02 -6.51713348e+02
#  -3.70908918e+02 -1.54128339e+03  5.01320874e+02 -1.07090034e+02
#   2.35733301e+02  3.40278384e+03 -2.52546414e+02  3.26175004e+02
#   4.31488588e+00]
# Ridge.intercept_: 181040.6240487064
# Ridge Test Performance:  0.8731529205790173

# %% [markdown]
# # Ridge Code

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler

ridge_pipe = Pipeline([
        ('scaler',StandardScaler()),
        ('ridge_reg',Ridge())])

ridge_params = {'ridge_reg__alpha':[0.001, 0.01,0.05, 0.1, 0.25,0.5,1, 10,100,150]}

grid_ridge = GridSearchCV(ridge_pipe,ridge_params,cv=5,return_train_score = True)

grid_ridge.fit(X_train,y_train)

X_train_preds = grid_ridge.predict(X_train)
X_test_preds = grid_ridge.predict(X_test)


print('best params ',grid_ridge.best_params_)
scores = cross_val_score(grid_ridge, X_train, y_train)
print("Cross-validation scores: {}".format(scores))
print('Cv score ',grid_ridge.best_score_)

print('train rmse',sqrt(mean_squared_error(y_train,X_train_preds)))
print("train r2: ", r2_score(y_train,X_train_preds))

print('test rmse',sqrt(mean_squared_error(y_test,X_test_preds)))
print("test r2: ", r2_score(y_test,X_test_preds))
print("Ridge Test Performance: ", grid_ridge.score(X_test,y_test))
# Out:
# best params  {'ridge_reg__alpha': 100}
# Cross-validation scores: [0.87180427 0.87337498 0.88443778 0.89665756 0.89454761]
# Cv score  0.8841976405377137
# train rmse 23661.930837005166
# train r2:  0.9103295889443214
# test rmse 29524.697349097773
# test r2:  0.8731529205790174
# Ridge Test Performance:  0.8731529205790174

# %%
'''
'__abstractmethods__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', 
'__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__',
'__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__',
'__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_check_is_fitted', 
'_estimator_type', '_format_results', '_get_param_names', '_get_tags', '_more_tags', '_pairwise',
'_required_parameters', '_run_search', 'best_estimator_', 'best_index_', 'best_params_', 'best_score_', 
'classes_', 'cv', 'cv_results_', 'decision_function', 'error_score', 'estimator', 'fit', 'get_params', 'iid', 
'inverse_transform', 'multimetric_', 'n_jobs', 'n_splits_', 'param_grid', 'pre_dispatch', 'predict', 
'predict_log_proba', 'predict_proba', 'refit', 'refit_time_', 'return_train_score', 'score', 'scorer_', 
'scoring', 'set_params', 'transform', 'verbose
'''

# %%
# Train a Lasso regression model, report the coefficients, the best parameters, and model performance 

# YOUR CODE HERE
'''
from sklearn.linear_model import Lasso
lasso = Lasso(random_state=0)

#define a list of parameters
param_lasso = {'alpha':[0.001, 0.01, 0.1, 1, 10, 100] }

grid_lasso = GridSearchCV(lasso, param_lasso, cv=5, return_train_score = True)
grid_lasso.fit(X_train, y_train)

# Mean Cross Validation Score
print("Best Mean Cross-validation score: {:.2f}".format(grid_lasso.best_score_))
print()

#find best parameters
print('Lasso parameters: ', grid_lasso.best_params_)

# print co-eff

print("Lasso.coef_:", grid_lasso.best_estimator_.coef_)
print("Lasso.intercept_:", grid_lasso.best_estimator_.intercept_)

# Check test data set performance
print("Lasso Test Performance: ", grid_lasso.score(X_test,y_test))
'''
# Out:
# Best Mean Cross-validation score: 0.88
#
# Lasso parameters:  {'alpha': 100}
# Lasso.coef_: [ 5.98354347e+02  9.93527379e+02  1.31248909e+03  2.45908267e+03
#   1.47831122e+03  2.01697431e+02  4.99595526e+02  1.10518248e+03
#   1.37589148e+03  2.21586305e+03  1.19134068e+03  1.12945939e+04
#   1.13951391e+03  2.01113271e+03  1.11030992e+03 -7.18291866e+02
#   1.58637889e+04 -2.48057120e+02 -4.75773676e+03  3.55362072e+03
#   3.04826646e+02 -7.97883492e+02  1.41798949e+03 -5.97053298e+02
#  -5.00534949e+02  0.00000000e+00  2.49235770e+03  6.28690101e+02
#  -0.00000000e+00  2.12280516e+03  3.56997127e+02  3.48335820e+03
#   1.03573161e+03  5.80099431e+03 -1.22600059e+03  1.78568161e+03
#  -1.93900166e+02  7.72000354e+03  1.02765199e+02  1.33679852e+03
#   1.22458458e+03 -4.25128495e+02  1.23009952e+04  1.13683366e+04
#   3.99723644e+03  5.84723766e+03  2.84083895e+03 -1.19002753e+03
#   3.90739089e+03  5.07525348e+03  5.97604436e+02  2.93758134e+03
#   3.76509853e+03  3.03646690e+03  2.87199457e+03  8.70912692e+02
#   1.35827672e+03 -1.63634329e+03 -1.60731811e+03 -7.16012142e+02
#   3.85437445e+03  4.69003975e+02  2.13068656e+03  4.15915245e+01
#   0.00000000e+00  1.27495552e+03  1.39525710e+03  0.00000000e+00
#   2.25974843e+03  2.59318123e+03 -1.16434500e+03 -2.21490338e-13
#  -1.97952878e+02 -1.71216733e+03  4.54375406e+02 -6.31134282e+01
#  -0.00000000e+00  4.10069748e+03 -0.00000000e+00  1.02306492e+02
#   0.00000000e+00]
# Lasso.intercept_: 181040.6240487064
# Lasso Test Performance:  0.877253397774493

# %% [markdown]
# # Lasso Code

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

lasso = Lasso(selection='random',max_iter=10000)

param_lasso = {'alpha':[0.001, 0.01,0.05, 0.1, 0.25,0.5,1, 10,100,150]}

grid_lasso = GridSearchCV(lasso,param_lasso,cv=10, return_train_score = True)

grid_lasso.fit(X_train,y_train)

X_train_preds = grid_lasso.predict(X_train)
X_test_preds = grid_lasso.predict(X_test)

print('CV Score',grid_lasso.best_score_)
print('Train RMSE',sqrt(mean_squared_error(y_train,X_train_preds)))
print('Test RMSE',sqrt(mean_squared_error(y_test,X_test_preds)))
print('Test Score/R-Square',grid_lasso.score(X_test,y_test))
# Out:
# CV Score 0.8856276597294205
# Train RMSE 23569.49807662688
# Test RMSE 28943.318674062088
# Test Score/R-Square 0.8780992953515048

# %% [markdown]
# # KNN Regressor Code

# %%
from sklearn.neighbors import KNeighborsRegressor

knn_pipe = Pipeline([
    ('scaler',StandardScaler()),
    ('knn_reg',KNeighborsRegressor(algorithm='auto'))
])

knn_params = {'knn_reg__weights':['uniform','distance'],
             'knn_reg__leaf_size': [5,10,20,30],
             'knn_reg__n_neighbors': [5,10,15],
             'knn_reg__p':[1,2,3]}

knn_reg_grid = GridSearchCV(knn_pipe,knn_params,cv=5,return_train_score = True)

knn_reg_grid.fit(X_train,y_train)

X_train_preds = knn_reg_grid.predict(X_train)
X_test_preds = knn_reg_grid.predict(X_test)

print("CV score ",knn_reg_grid.best_score_)
print("Best Params ",knn_reg_grid.best_params_)

print("train RMSE",sqrt(mean_squared_error(y_train,X_train_preds)))
print("train R2/score",r2_score(y_train,X_train_preds))

print("test RMSE",sqrt(mean_squared_error(y_test,X_test_preds)))
print("test R2/score",r2_score(y_test,X_test_preds))
# Out:
# CV score  0.8354252209693938
# Best Params  {'knn_reg__leaf_size': 5, 'knn_reg__n_neighbors': 5, 'knn_reg__p': 1, 'knn_reg__weights': 'distance'}
# train RMSE 165.80829186118498
# train R2/score 0.9999955968722103
# test RMSE 38002.05080871088
# test R2/score 0.7898527883440282

# %% [markdown]
# # DecisionTree Regressor code

# %%
from sklearn.tree import DecisionTreeRegressor

dreg_pipe = Pipeline([
    ('dtree_reg',DecisionTreeRegressor())
])

dreg_params = {
    'dtree_reg__criterion':['mse'],
    'dtree_reg__splitter':['random'],
    'dtree_reg__max_depth':[20,30],
    'dtree_reg__min_samples_split':[4,8,12,16],
    'dtree_reg__min_samples_leaf' :[2,4,8],
    'dtree_reg__max_features':['auto']
}

dtree_reg_grid = GridSearchCV(dreg_pipe,dreg_params,cv=5,return_train_score = True)

dtree_reg_grid.fit(X_train,y_train)

X_train_preds = dtree_reg_grid.predict(X_train)
X_test_preds = dtree_reg_grid.predict(X_test)

print("CV score ",dtree_reg_grid.best_score_)
print("Best Params ",dtree_reg_grid.best_params_)

print("train RMSE",sqrt(mean_squared_error(y_train,X_train_preds)))
print("train R2/score",r2_score(y_train,X_train_preds))

print("test RMSE",sqrt(mean_squared_error(y_test,X_test_preds)))
print("test R2/score",r2_score(y_test,X_test_preds))

'''
CV score  0.7814859520165511
Best Params  {'dtree_reg__criterion': 'friedman_mse', 'dtree_reg__max_depth': 20, 'dtree_reg__max_features': 'auto', 'dtree_reg__min_samples_leaf': 2, 'dtree_reg__min_samples_split': 8, 'dtree_reg__splitter': 'random'}
train RMSE 16912.129029241747
train R2/score 0.9541915743480076
test RMSE 35541.86940384073
test R2/score 0.8161811279310636
'''
# Out:
# CV score  0.7769693808969332
# Best Params  {'dtree_reg__criterion': 'mse', 'dtree_reg__max_depth': 20, 'dtree_reg__max_features': 'auto', 'dtree_reg__min_samples_leaf': 8, 'dtree_reg__min_samples_split': 8, 'dtree_reg__splitter': 'random'}
# train RMSE 28385.474121453717
# train R2/score 0.8709550229687751
# test RMSE 42146.89328538794
# test R2/score 0.7415118141191931
# "\nCV score  0.7814859520165511\nBest Params  {'dtree_reg__criterion': 'friedman_mse', 'dtree_reg__max_depth': 20, 'dtree_reg__max_features': 'auto', 'dtree_reg__min_samples_leaf': 2, 'dtree_reg__min_samples_split': 8, 'dtree_reg__splitter': 'random'}\ntrain RMSE 16912.129029241747\ntrain R2/score 0.9541915743480076\ntest RMSE 35541.86940384073\ntest R2/score 0.8161811279310636\n"

# %% [markdown]
# # SVM Regressor

# %%
from sklearn.svm import SVR

svm_reg_pipe = Pipeline([
    ('svm_reg',SVR())
])

svm_reg_params = {
    'svm_reg__kernel':['linear','poly','rbf','sigmoid'],
    'svm_reg__degree':[3,4,5],
    'svm_reg__gamma': ['auto','scale'],
    'svm_reg__coef0':[2.0,4.0,10.0,15.0]
}

svm_reg_grid = GridSearchCV(svm_reg_pipe,svm_reg_params,cv=5,return_train_score = True)

svm_reg_grid.fit(X_train,y_train)

X_train_preds = svm_reg_grid.predict(X_train)
X_test_preds = svm_reg_grid.predict(X_test)

print("CV score ",svm_reg_grid.best_score_)
print("Best Params ",svm_reg_grid.best_params_)

print("train RMSE",sqrt(mean_squared_error(y_train,X_train_preds)))
print("train R2/score",r2_score(y_train,X_train_preds))

print("test RMSE",sqrt(mean_squared_error(y_test,X_test_preds)))
print("test R2/score",r2_score(y_test,X_test_preds))
# Out:
# CV score  0.9004499345276106
# Best Params  {'svm_reg__coef0': 10.0, 'svm_reg__degree': 5, 'svm_reg__gamma': 'auto', 'svm_reg__kernel': 'poly'}
# train RMSE 17044.420472834856
# train R2/score 0.9534721185647854
# test RMSE 29404.570032081163
# test R2/score 0.8741830276841772

# %% [markdown]
# ## Tune Multiple Models with one GridSearch

# %%
model_gs = Pipeline([("Poly",PolynomialFeatures()),("regressor", LinearRegression())])

# %%
model_parm_gd = [
    { 'regressor': [LinearRegression()]},
    
    { 'regressor': [Ridge()],
      'regressor__alpha':[0.001, 0.01, 0.1, 1, 10, 100,200],
    'regressor__solver':['auto']},
    
    { 'regressor': [Lasso()],
      'regressor__alpha':[0.001, 0.01, 0.1, 1, 10, 100,200]},
 
]

# %%
grid_search_house_pipe = GridSearchCV(model_gs, model_parm_gd,cv=5)

# %%
grid_search_house_pipe.fit(X_train,y_train)
# Out:
# /opt/anaconda3/envs/buan6341/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2236734277.5811195, tolerance: 657118734.8147435
#   positive)
# /opt/anaconda3/envs/buan6341/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2314463065.5480876, tolerance: 655974723.0327224
#   positive)
# /opt/anaconda3/envs/buan6341/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2206285636.38415, tolerance: 635955900.9288123
#   positive)
# /opt/anaconda3/envs/buan6341/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2290521048.545657, tolerance: 642749145.1567798
#   positive)
# /opt/anaconda3/envs/buan6341/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2415103080.3513923, tolerance: 689033704.679551
#   positive)
# /opt/anaconda3/envs/buan6341/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10735084585.176062, tolerance: 657118734.8147435
#   positive)
# /opt/anaconda3/envs/buan6341/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10918738110.095474, tolerance: 655974723.0327224
#   positive)
# /opt/anaconda3/envs/buan6341/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11865667864.470778, tolerance: 635955900.9288123
#   positive)
# /opt/anaconda3/envs/buan6341/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12090478090.541023, tolerance: 642749145.1567798
#   positive)
# /opt/anaconda3/envs/buan6341/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10703341660.377636, tolerance: 689033704.679551
#   positive)
# /opt/anaconda3/envs/buan6341/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2647202394.4553223, tolerance: 657118734.8147435
#   positive)
# /opt/anaconda3/envs/buan6341/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1494749218.5318146, tolerance: 655974723.0327224
#   positive)
# /opt/anaconda3/envs/buan6341/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1058959564.560852, tolerance: 635955900.9288123
#   positive)
# /opt/anaconda3/envs/buan6341/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1584225201.543045, tolerance: 642749145.1567798
#   positive)
# /opt/anaconda3/envs/buan6341/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6629443019.999504, tolerance: 689033704.679551
#   positive)
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('Poly',
#                                         PolynomialFeatures(degree=2,
#                                                            include_bias=True,
#                                                            interaction_only=False,
#                                                            order='C')),
#                                        ('regressor',
#                                         LinearRegression(copy_X=True,
#                                                          fit_intercept=True,
#                                                          n_jobs=None,
#                                                          normalize=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'regressor': [LinearRegression(copy_X=Tru...
#                           'regressor__solver': ['auto']},
#                          {'regressor': [Lasso(alpha=200, copy_X=True,
#                                               fit_intercept=True, max_iter=1000,
#                                               normalize=False, positive=False,
#                                               precompute=False,
#                                               random_state=None,
#                                               selection='cyclic', tol=0.0001,
#                                               warm_start=False)],
#                           'regressor__alpha': [0.001, 0.01, 0.1, 1, 10, 100,
#                                                200]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
#print(grid_search_house_pipe.best_params_)
# Out:
# {'regressor': Ridge(alpha=100, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001), 'regressor__alpha': 100}

# %%
print(grid_search_house_pipe.best_params_)
# Out:
# {'regressor': Lasso(alpha=200, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'regressor__alpha': 200}

# %%
# let's get the predictions
X_train_preds = grid_search_house_pipe.predict(X_train)
X_test_preds = grid_search_house_pipe.predict(X_test)

# %%
#print("Best Mean Cross-validation score: {:.2f}".format(grid_search_house_pipe.best_score_))
# Out:
# Best Mean Cross-validation score: 0.88

# %%
print("Best Mean Cross-validation score: {:.2f}".format(grid_search_house_pipe.best_score_))
# Out:
# Best Mean Cross-validation score: 0.83

# %%
'''
# check model performance:
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

print('train mse: {}'.format(mean_squared_error(y_train, X_train_preds)))
print('train rmse: {}'.format(sqrt(mean_squared_error(y_train, X_train_preds))))
print('train r2: {}'.format(r2_score(y_train, X_train_preds)))
print()
print('test mse: {}'.format(mean_squared_error(y_test, X_test_preds)))
print('test rmse: {}'.format(sqrt(mean_squared_error(y_test, X_test_preds))))
print('test r2: {}'.format(r2_score(y_test, X_test_preds)))

'''
# Out:
# train mse: 559886970.9352162
# train rmse: 23661.93083700517
# train r2: 0.9103295889443213
#
# test mse: 871707753.5558217
# test rmse: 29524.697349097783
# test r2: 0.8731529205790173

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

print('train mse: {}'.format(mean_squared_error(y_train, X_train_preds)))
print('train rmse: {}'.format(sqrt(mean_squared_error(y_train, X_train_preds))))
print('train r2: {}'.format(r2_score(y_train, X_train_preds)))
print()
print('test mse: {}'.format(mean_squared_error(y_test, X_test_preds)))
print('test rmse: {}'.format(sqrt(mean_squared_error(y_test, X_test_preds))))
print('test r2: {}'.format(r2_score(y_test, X_test_preds)))
# Out:
# train mse: 112781889.48419684
# train rmse: 10619.881801799718
# train r2: 0.981937071382834
#
# test mse: 865352885.5659168
# test rmse: 29416.88096256836
# test r2: 0.8740776530267179

# %%
## Bagging 
len(X_train)
# Out:
# 1314

# %% [markdown]
# # Ensemble Models

# %% [markdown]
# ## Bagging Using Linear Regression

# %%
from sklearn.ensemble import BaggingRegressor

bag_lreg = BaggingRegressor(LinearRegression(),bootstrap=True,oob_score=True)
bag_lreg_param= {'n_estimators':[20,40],'max_samples':[0.7,1]}

bag_lreg_grid = GridSearchCV(bag_lreg,bag_lreg_param,cv=10)
bag_lreg_grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10, error_score=nan,
#              estimator=BaggingRegressor(base_estimator=LinearRegression(copy_X=True,
#                                                                         fit_intercept=True,
#                                                                         n_jobs=None,
#                                                                         normalize=False),
#                                         bootstrap=True,
#                                         bootstrap_features=False,
#                                         max_features=1.0, max_samples=1.0,
#                                         n_estimators=10, n_jobs=None,
#                                         oob_score=True, random_state=None,
#                                         verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'max_samples': [0.7, 1], 'n_estimators': [20, 40]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
X_train_preds = bag_lreg_grid.predict(X_train)
X_test_preds = bag_lreg_grid.predict(X_test)

#print('Co-efficients',dir(reg_poly_pipe.named_steps['lreg']))
print('best params',bag_lreg_grid.best_params_)
print('CV Score: ',bag_lreg_grid.best_score_)

print("Train Score/r2: ", r2_score(y_train,X_train_preds))
print("Test Score/r2: ", r2_score(y_test,X_test_preds))
# Out:
# best params {'max_samples': 1, 'n_estimators': 40}
# CV Score:  -0.02097959514875323
# Train Score/r2:  -0.008544999909401163
# Test Score/r2:  -0.010510119801462992

# %% [markdown]
# ## Bagging using best model (Polynomial Regression)

# %%
poly_reg_pipeline = Pipeline([('poly',PolynomialFeatures()),('lreg',LinearRegression())])


bag_preg = BaggingRegressor(base_estimator=poly_reg_pipeline,bootstrap=True,oob_score=True)
bag_preg_params = {
                 'base_estimator__poly__degree': range(1,3),  
                 'n_estimators':[20,40],
                 'max_samples':[0.8]}
bag_preg_grid = GridSearchCV(bag_preg,bag_preg_params,cv=5)
bag_preg_grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=BaggingRegressor(base_estimator=Pipeline(memory=None,
#                                                                 steps=[('poly',
#                                                                         PolynomialFeatures(degree=2,
#                                                                                            include_bias=True,
#                                                                                            interaction_only=False,
#                                                                                            order='C')),
#                                                                        ('lreg',
#                                                                         LinearRegression(copy_X=True,
#                                                                                          fit_intercept=True,
#                                                                                          n_jobs=None,
#                                                                                          normalize=False))],
#                                                                 verbose=False),
#                                         bootstrap=True,
#                                         bootstrap_features=False,
#                                         max_features=1.0, max_samples=1.0,
#                                         n_estimators=10, n_jobs=None,
#                                         oob_score=True, random_state=None,
#                                         verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'base_estimator__poly__degree': range(1, 3),
#                          'max_samples': [0.8], 'n_estimators': [20, 40]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
X_train_preds = bag_preg_grid.predict(X_train)
X_test_preds = bag_preg_grid.predict(X_test)

#print('Co-efficients',dir(reg_poly_pipe.named_steps['lreg']))
print('best params',bag_preg_grid.best_params_)
print('CV Score: ',bag_preg_grid.best_score_)

print("Train Score/r2: ", r2_score(y_train,X_train_preds))
print("Test Score/r2: ", r2_score(y_test,X_test_preds))
# Out:
# best params {'base_estimator__poly__degree': 2, 'max_samples': 0.8, 'n_estimators': 20}
# CV Score:  -1.7984961372332154e+17
# Train Score/r2:  -2616476435060959.0
# Test Score/r2:  -5947515258061041.0

# %% [markdown]
# ## Bagging Using Decision Tree

# %%
bag_dtree_reg = BaggingRegressor(base_estimator=DecisionTreeRegressor(),bootstrap=True,oob_score=True)

bag_dtree_reg_params = {
    'base_estimator__splitter':['random'],
    'base_estimator__max_depth':[20,30],
    'base_estimator__min_samples_split':[4,8,12,16],
    'base_estimator__min_samples_leaf' :[2,4,8],
    'base_estimator__max_features':['auto'],
    'n_estimators':[20,40],
    'max_samples':[0.8]
}

bag_dtree_grid = GridSearchCV(bag_dtree_reg,bag_dtree_reg_params,cv=5)
bag_dtree_grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=BaggingRegressor(base_estimator=DecisionTreeRegressor(ccp_alpha=0.0,
#                                                                              criterion='mse',
#                                                                              max_depth=None,
#                                                                              max_features=None,
#                                                                              max_leaf_nodes=None,
#                                                                              min_impurity_decrease=0.0,
#                                                                              min_impurity_split=None,
#                                                                              min_samples_leaf=1,
#                                                                              min_samples_split=2,
#                                                                              min_weight_fraction_leaf=0.0,
#                                                                              presort='deprecated',
#                                                                              random_state=None,
#                                                                              splitter='be...
#              iid='deprecated', n_jobs=None,
#              param_grid={'base_estimator__max_depth': [20, 30],
#                          'base_estimator__max_features': ['auto'],
#                          'base_estimator__min_samples_leaf': [2, 4, 8],
#                          'base_estimator__min_samples_split': [4, 8, 12, 16],
#                          'base_estimator__splitter': ['random'],
#                          'max_samples': [0.8], 'n_estimators': [20, 40]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
X_train_preds = bag_dtree_grid.predict(X_train)
X_test_preds = bag_dtree_grid.predict(X_test)

#print('Co-efficients',dir(reg_poly_pipe.named_steps['lreg']))
print('best params',bag_dtree_grid.best_params_)
print('CV Score: ',bag_dtree_grid.best_score_)

print("Train Score/r2: ", r2_score(y_train,X_train_preds))
print("Test Score/r2: ", r2_score(y_test,X_test_preds))
# Out:
# best params {'base_estimator__max_depth': 20, 'base_estimator__max_features': 'auto', 'base_estimator__min_samples_leaf': 2, 'base_estimator__min_samples_split': 4, 'base_estimator__splitter': 'random', 'max_samples': 0.8, 'n_estimators': 40}
# CV Score:  0.8714664281170718
# Train Score/r2:  0.9610917009747506
# Test Score/r2:  0.8552559283874988

# %% [markdown]
# ## Pasting Using Best Model (Polynomial Regression)

# %%
poly_reg2_pipeline = Pipeline([('poly',PolynomialFeatures()),
                             ('lreg',LinearRegression())])


paste_preg = BaggingRegressor(poly_reg2_pipeline,bootstrap=False,oob_score=False)
paste_preg_params = {'base_estimator__poly__degree': range(1,3),
                 'n_estimators':[20,40],
                 'max_samples':[0.8,1]}
paste_preg_grid = GridSearchCV(paste_preg,paste_preg_params,cv=5)
paste_preg_grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=BaggingRegressor(base_estimator=Pipeline(memory=None,
#                                                                 steps=[('poly',
#                                                                         PolynomialFeatures(degree=2,
#                                                                                            include_bias=True,
#                                                                                            interaction_only=False,
#                                                                                            order='C')),
#                                                                        ('lreg',
#                                                                         LinearRegression(copy_X=True,
#                                                                                          fit_intercept=True,
#                                                                                          n_jobs=None,
#                                                                                          normalize=False))],
#                                                                 verbose=False),
#                                         bootstrap=False,
#                                         bootstrap_features=False,
#                                         max_features=1.0, max_samples=1.0,
#                                         n_estimators=10, n_jobs=None,
#                                         oob_score=False, random_state=None,
#                                         verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'base_estimator__poly__degree': range(1, 3),
#                          'max_samples': [0.8, 1], 'n_estimators': [20, 40]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
X_train_preds = paste_preg_grid.predict(X_train)
X_test_preds = paste_preg_grid.predict(X_test)

#print('Co-efficients',dir(reg_poly_pipe.named_steps['lreg']))
print('best params',paste_preg_grid.best_params_)
print('CV Score: ',paste_preg_grid.best_score_)

print("Train Score/r2: ", r2_score(y_train,X_train_preds))
print("Test Score/r2: ", r2_score(y_test,X_test_preds))
# Out:
# best params {'base_estimator__poly__degree': 1, 'max_samples': 1, 'n_estimators': 20}
# CV Score:  -0.018930924946367656
# Train Score/r2:  -0.13345775058904574
# Test Score/r2:  -0.11143062071558263

# %% [markdown]
# ## Pasting using Decision Tree

# %%
paste_dtree_reg = BaggingRegressor(base_estimator=DecisionTreeRegressor(),bootstrap=False,oob_score=False)

paste_dtree_reg_params = {
    'base_estimator__criterion':['mse'],
    'base_estimator__splitter':['random'],
    'base_estimator__max_depth':[20,30],
    'base_estimator__min_samples_split':[4,8,12,16],
    'base_estimator__min_samples_leaf' :[2,4,8],
    'base_estimator__max_features':['auto'],
    'n_estimators':[20,40],
    'max_samples':[0.8,1]
}

paste_dtree_grid = GridSearchCV(paste_dtree_reg,paste_dtree_reg_params,cv=5)
paste_dtree_grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=BaggingRegressor(base_estimator=DecisionTreeRegressor(ccp_alpha=0.0,
#                                                                              criterion='mse',
#                                                                              max_depth=None,
#                                                                              max_features=None,
#                                                                              max_leaf_nodes=None,
#                                                                              min_impurity_decrease=0.0,
#                                                                              min_impurity_split=None,
#                                                                              min_samples_leaf=1,
#                                                                              min_samples_split=2,
#                                                                              min_weight_fraction_leaf=0.0,
#                                                                              presort='deprecated',
#                                                                              random_state=None,
#                                                                              splitter='be...
#              param_grid={'base_estimator__criterion': ['mse'],
#                          'base_estimator__max_depth': [20, 30],
#                          'base_estimator__max_features': ['auto'],
#                          'base_estimator__min_samples_leaf': [2, 4, 8],
#                          'base_estimator__min_samples_split': [4, 8, 12, 16],
#                          'base_estimator__splitter': ['random'],
#                          'max_samples': [0.8, 1], 'n_estimators': [20, 40]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
X_train_preds = paste_dtree_grid.predict(X_train)
X_test_preds = paste_dtree_grid.predict(X_test)

#print('Co-efficients',dir(reg_poly_pipe.named_steps['lreg']))
print('best params',paste_dtree_grid.best_params_)
print('CV Score: ',paste_dtree_grid.best_score_)

print("Train Score/r2: ", r2_score(y_train,X_train_preds))
print("Test Score/r2: ", r2_score(y_test,X_test_preds))
# Out:
# best params {'base_estimator__criterion': 'mse', 'base_estimator__max_depth': 20, 'base_estimator__max_features': 'auto', 'base_estimator__min_samples_leaf': 2, 'base_estimator__min_samples_split': 4, 'base_estimator__splitter': 'random', 'max_samples': 0.8, 'n_estimators': 40}
# CV Score:  0.8775043727754538
# Train Score/r2:  0.9846583119441495
# Test Score/r2:  0.8689652157950667

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

rf_reg = RandomForestRegressor(bootstrap=True,oob_score=True)

rf_reg_param = {'n_estimators':[20,40],
               'max_samples':[0.7,1],
               'max_depth':[20, 30],
               'min_samples_leaf':[2, 4, 8],
               'min_samples_split': [4, 8, 12, 16]}

rf_reg_grid = GridSearchCV(rf_reg,rf_reg_param,cv=5)
rf_reg_grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=True, random_state=None,
#                                              verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'max_depth': [20, 30], 'max_samples': [0.7, 1],
#                          'min_samples_leaf': [2, 4, 8],
#                          'min_samples_split': [4, 8, 12, 16],
#                          'n_estimators': [20, 40]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
X_train_preds = rf_reg_grid.predict(X_train)
X_test_preds = rf_reg_grid.predict(X_test)

#print('Co-efficients',dir(reg_poly_pipe.named_steps['lreg']))
print('best params',rf_reg_grid.best_params_)
print('CV Score: ',rf_reg_grid.best_score_)

print("Train Score/r2: ", r2_score(y_train,X_train_preds))
print("Test Score/r2: ", r2_score(y_test,X_test_preds))
# Out:
# best params {'max_depth': 30, 'max_samples': 0.7, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 40}
# CV Score:  0.8680854208640751
# Train Score/r2:  0.9562939090417061
# Test Score/r2:  0.8673533671009988

# %% [markdown]
# ## AdaBoost Regressor

# %%
from sklearn.ensemble import AdaBoostRegressor

ada_reg = AdaBoostRegressor(base_estimator=DecisionTreeRegressor())
ada_reg_param = {
                'base_estimator__max_depth': range(2,6),
                'base_estimator__min_samples_leaf': [5,10,15],
                'base_estimator__max_leaf_nodes': range(2,10),
                'base_estimator__min_impurity_decrease':[0.005,0.05,0.1],
                'n_estimators':[20,40],
                'learning_rate' : [0.5,1.0,2]
                }

ada_reg_grid = GridSearchCV(ada_reg, ada_reg_param,cv=5, return_train_score=True, )
ada_reg_grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(ccp_alpha=0.0,
#                                                                               criterion='mse',
#                                                                               max_depth=None,
#                                                                               max_features=None,
#                                                                               max_leaf_nodes=None,
#                                                                               min_impurity_decrease=0.0,
#                                                                               min_impurity_split=None,
#                                                                               min_samples_leaf=1,
#                                                                               min_samples_split=2,
#                                                                               min_weight_fraction_leaf=0.0,
#                                                                               presort='deprecated',
#                                                                               random_state=None,
#                                                                               splitter='b...
#              iid='deprecated', n_jobs=None,
#              param_grid={'base_estimator__max_depth': range(2, 6),
#                          'base_estimator__max_leaf_nodes': range(2, 10),
#                          'base_estimator__min_impurity_decrease': [0.005, 0.05,
#                                                                    0.1],
#                          'base_estimator__min_samples_leaf': [5, 10, 15],
#                          'learning_rate': [0.5, 1.0, 2],
#                          'n_estimators': [20, 40]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring=None, verbose=0)

# %%
X_train_preds = ada_reg_grid.predict(X_train)
X_test_preds = ada_reg_grid.predict(X_test)

#print('Co-efficients',dir(reg_poly_pipe.named_steps['lreg']))
print('best params',ada_reg_grid.best_params_)
print('CV Score: ',ada_reg_grid.best_score_)

print("Train Score/r2: ", r2_score(y_train,X_train_preds))
print("Test Score/r2: ", r2_score(y_test,X_test_preds))
# Out:
# best params {'base_estimator__max_depth': 5, 'base_estimator__max_leaf_nodes': 9, 'base_estimator__min_impurity_decrease': 0.05, 'base_estimator__min_samples_leaf': 10, 'learning_rate': 2, 'n_estimators': 40}
# CV Score:  0.8247415104118545
# Train Score/r2:  0.8815435500586578
# Test Score/r2:  0.8342278245892305

# %% [markdown]
# ## GradientBoost Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

gboost_reg = GradientBoostingRegressor()
gboost_reg_param = {
              'max_depth' : range(2,6),
              'n_estimators' : [100,150],
              'learning_rate' : [0.5,1.0,2],
             }

gboost_reg_grid = GridSearchCV(gboost_reg, gboost_reg_param,cv=5, return_train_score=True )
gboost_reg_grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0,
#                                                  criterion='friedman_mse',
#                                                  init=None, learning_rate=0.1,
#                                                  loss='ls', max_depth=3,
#                                                  max_features=None,
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  n_estimators=100,
#                                                  n_iter_no_change=None,
#                                                  presort='deprecated',
#                                                  random_state=None,
#                                                  subsample=1.0, tol=0.0001,
#                                                  validation_fraction=0.1,
#                                                  verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.5, 1.0, 2],
#                          'max_depth': range(2, 6), 'n_estimators': [100, 150]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring=None, verbose=0)

# %%
X_train_preds = gboost_reg_grid.predict(X_train)
X_test_preds = gboost_reg_grid.predict(X_test)

#print('Co-efficients',dir(reg_poly_pipe.named_steps['lreg']))
print('best params',gboost_reg_grid.best_params_)
print('CV Score: ',gboost_reg_grid.best_score_)

print("Train Score/r2: ", r2_score(y_train,X_train_preds))
print("Test Score/r2: ", r2_score(y_test,X_test_preds))
# Out:
# best params {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 100}
# CV Score:  0.8779305773463723
# Train Score/r2:  0.9845482194901631
# Test Score/r2:  0.8868899381505375

# %% [markdown]
# ## XGBoost

# %%
from  xgboost import XGBRegressor

xgb_reg= XGBRegressor(random_state=42,early_stopping_rounds=2,objective= 'reg:linear',silent=True)
xgb_reg_param = {
              'max_depth' : [2,4,6],
              'n_estimators' : [20,40],
              'learning_rate' : [0.5,0.8],
               'min_child_weight' : [1,3,5,7],
                'subsample':[0.8,1]
             }
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
xgb_reg_grid = GridSearchCV(xgb_reg, xgb_reg_param,cv=5, return_train_score=True)
xgb_reg_grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, early_stopping_rounds=2,
#                                     gamma=0, importance_type='gain',
#                                     learning_rate=0.1, max_delta_step=0,
#                                     max_depth=3, min_child_weight=1,
#                                     missing=None, n_estimators=100, n_jobs=1,
#                                     nthread=None, objective='reg:linear',
#                                     random_state=42, reg_alpha=0, reg_lambda=1,
#                                     scale_pos_weight=1, seed=None, silent=True,
#                                     subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.5, 0.8], 'max_depth': [2, 4, 6],
#                          'min_child_weight': [1, 3, 5, 7],
#                          'n_estimators': [20, 40], 'subsample': [0.8, 1]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring=None, verbose=0)

# %%
X_train_preds = xgb_reg_grid.predict(X_train)
X_test_preds = xgb_reg_grid.predict(X_test)

#print('Co-efficients',dir(reg_poly_pipe.named_steps['lreg']))
print('best params',xgb_reg_grid.best_params_)
print('CV Score: ',xgb_reg_grid.best_score_)

print("Train Score/r2: ", r2_score(y_train,X_train_preds))
print("Test Score/r2: ", r2_score(y_test,X_test_preds))

#XGBoost Result #1
# Out:
# best params {'learning_rate': 0.5, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 40, 'subsample': 1}
# CV Score:  0.8763193906415836
# Train Score/r2:  0.9786917944563617
# Test Score/r2:  0.8667388468544738

# %%
'''
XGBoost Result #2
best params {'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 150, 'subsample': 0.8}
CV Score:  0.8981992683459357
Train Score/r2:  0.979396879296572
Test Score/r2:  0.8776048030903614
'''

# %% [markdown]
# ## Extra Tree Regressor

# %%
from  sklearn.ensemble import ExtraTreesRegressor

et_reg= ExtraTreesRegressor(random_state=42)
et_reg_param = { 
    'n_estimators': [20,50],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [2,6,8,10],
}
et_reg_grid = GridSearchCV(et_reg,et_reg_param,cv=5, return_train_score=True)
et_reg_grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0,
#                                            criterion='mse', max_depth=None,
#                                            max_features='auto',
#                                            max_leaf_nodes=None,
#                                            max_samples=None,
#                                            min_impurity_decrease=0.0,
#                                            min_impurity_split=None,
#                                            min_samples_leaf=1,
#                                            min_samples_split=2,
#                                            min_weight_fraction_leaf=0.0,
#                                            n_estimators=100, n_jobs=None,
#                                            oob_score=False, random_state=42,
#                                            verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'max_depth': [2, 6, 8, 10],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [20, 50]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring=None, verbose=0)

# %%
X_train_preds = et_reg_grid.predict(X_train)
X_test_preds = et_reg_grid.predict(X_test)

#print('Co-efficients',dir(reg_poly_pipe.named_steps['lreg']))
print('best params',et_reg_grid.best_params_)
print('CV Score: ',et_reg_grid.best_score_)

print("Train Score/r2: ", r2_score(y_train,X_train_preds))
print("Test Score/r2: ", r2_score(y_test,X_test_preds))
# Out:
# best params {'max_depth': 10, 'max_features': 'auto', 'n_estimators': 50}
# CV Score:  0.8714797938251614
# Train Score/r2:  0.9895590470988999
# Test Score/r2:  0.8558849734642543

# %%
regressors = {'knn_reg':knn_reg_grid ,
              'lasso_reg':grid_lasso,
              'ridge_reg':grid_ridge,
              'sgd_reg':grid_sgd,
              'poly_reg':reg_poly_grid,
             'lr':lr_grid,
             'svm':svm_reg_grid,
             'dtree_reg':dtree_reg_grid,
             'bag_dtree':bag_dtree_grid,
             'bag_preg': bag_preg_grid,
            'paste_dtree': paste_dtree_grid,
             'paste_preg': paste_preg_grid,
             'rf_reg': rf_reg_grid,
             'et_reg': et_reg_grid,
             'ada_dtree':ada_reg_grid,
             'gboost': gboost_reg_grid,
             'xgb': xgb_reg_grid}

# %%
regressors.keys()
# Out:
# dict_keys(['knn_reg', 'lasso_reg', 'ridge_reg', 'sgd_reg', 'poly_reg', 'lr', 'svm', 'dtree_reg', 'bag_dtree', 'bag_preg', 'paste_dtree', 'paste_preg', 'rf_reg', 'et_reg', 'ada_dtree', 'gboost', 'xgb'])

# %%
results_mean_std = []
for  key, value in regressors.items():
    mean = value.cv_results_['mean_test_score'][value.best_index_]
    std=value.cv_results_['std_test_score'][value.best_index_]
     
    results_mean_std.append({
        "model": key,
        "mean": mean,
        "std": std
    })

# %%
accuracy_df = pd.DataFrame(results_mean_std, columns=['model', 'mean', 'std'])
accuracy_df.sort_values(by=['mean'], inplace=True,ascending=False)
accuracy_df
# Out:
#           model          mean           std
# 6           svm  9.004499e-01  2.227632e-02
# 16          xgb  8.981993e-01  9.513393e-03
# 1     lasso_reg  8.856277e-01  3.042557e-02
# 2     ridge_reg  8.841976e-01  1.063922e-02
# 3       sgd_reg  8.803641e-01  1.801103e-02
# 15       gboost  8.779306e-01  1.738114e-02
# 10  paste_dtree  8.775044e-01  1.971525e-02
# 8     bag_dtree  8.754637e-01  1.771028e-02
# 13       et_reg  8.714798e-01  1.553661e-02
# 12       rf_reg  8.680854e-01  1.532216e-02
# 0       knn_reg  8.354252e-01  1.840664e-02
# 14    ada_dtree  8.247415e-01  1.220507e-02
# 7     dtree_reg  7.769694e-01  1.915138e-02
# 9      bag_preg -1.223523e-02  1.378589e-02
# 11   paste_preg -3.648151e-02  3.305732e-02
# 4      poly_reg -2.168230e+20  4.336461e+20
# 5            lr -7.087904e+23  2.126371e+24

# %%
# Create a prediction of all models on the test set
predictions_all = {}
for  key, value in regressors.items():
    # Get best estimator
    best_model = value.best_estimator_
    
    # Predict test labels
    predictions = best_model.predict(X_test)
    
    # Save predictions to a list
    predictions_all[key] = predictions

# %%
pred = pd.DataFrame(predictions_all)

# %%
# Plot a heatmap of all correlations for easier visualization
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(9,6))
g = sns.heatmap(pred.corr(), annot=True, cmap='coolwarm', ax=ax)
g.set_title('Correlation of the test set label prediction between models')
# Out:
# Text(0.5, 1, 'Correlation of the test set label prediction between models')

# %% [markdown]
# ## Voting top 5 models

# %%
from sklearn.ensemble import VotingRegressor

voting_reg = VotingRegressor(estimators=[('xgb', xgb_reg_grid), 
                                          ('svm', svm_reg_grid),
                                          ('lasso',grid_lasso),
                                         ('ridge',grid_ridge),
                                         ('sgd',grid_sgd)])
voting_reg.fit(X_train, y_train)

for reg in (xgb_reg_grid, svm_reg_grid, grid_lasso,grid_ridge,grid_sgd,voting_reg):
    reg.fit(X_train, y_train)
    y_pred = reg.predict(X_test)
    print(reg.__class__.__name__, r2_score(y_test, y_pred))
# Out:
# -- Epoch 1
# Norm: 88296.42, NNZs: 81, Bias: 582.470775, T: 1051, Avg. loss: 622966350.773162
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 96320.08, NNZs: 81, Bias: 547.236275, T: 2102, Avg. loss: 420788726.533961
# Total training time: 0.01 seconds.
# -- Epoch 3
# Norm: 107123.65, NNZs: 81, Bias: -1276.256018, T: 3153, Avg. loss: 355939968.533664
# Total training time: 0.01 seconds.
# -- Epoch 4
# Norm: 117952.37, NNZs: 81, Bias: -2674.328949, T: 4204, Avg. loss: 348682352.096593
# Total training time: 0.01 seconds.
# -- Epoch 5
# Norm: 122780.25, NNZs: 81, Bias: -2941.483657, T: 5255, Avg. loss: 343794224.855757
# Total training time: 0.02 seconds.
# -- Epoch 6
# Norm: 128232.31, NNZs: 81, Bias: -2861.905855, T: 6306, Avg. loss: 328768999.066469
# Total training time: 0.02 seconds.
# -- Epoch 7
# Norm: 133747.94, NNZs: 81, Bias: -4013.032519, T: 7357, Avg. loss: 332347380.994939
# Total training time: 0.02 seconds.
# -- Epoch 8
# Norm: 138809.19, NNZs: 81, Bias: -5097.454127, T: 8408, Avg. loss: 316555986.737475
# Total training time: 0.02 seconds.
# -- Epoch 9
# Norm: 140003.56, NNZs: 81, Bias: -5069.102570, T: 9459, Avg. loss: 321487309.132571
# Total training time: 0.02 seconds.
# -- Epoch 10
# Norm: 140969.20, NNZs: 81, Bias: -5884.000156, T: 10510, Avg. loss: 257061186.330388
# Total training time: 0.03 seconds.
# -- Epoch 11
# Norm: 141785.79, NNZs: 81, Bias: -5943.422068, T: 11561, Avg. loss: 257690830.961857
# Total training time: 0.03 seconds.
# -- Epoch 12
# Norm: 141982.80, NNZs: 81, Bias: -6063.719437, T: 12612, Avg. loss: 257821852.625293
# Total training time: 0.03 seconds.
# -- Epoch 13
# Norm: 143407.45, NNZs: 81, Bias: -6113.264441, T: 13663, Avg. loss: 253255943.951260
# Total training time: 0.03 seconds.
# -- Epoch 14
# Norm: 143649.91, NNZs: 81, Bias: -6427.473794, T: 14714, Avg. loss: 256754167.675191
# Total training time: 0.03 seconds.
# -- Epoch 15
# Norm: 143874.43, NNZs: 81, Bias: -6288.178269, T: 15765, Avg. loss: 247054753.592502
# Total training time: 0.04 seconds.
# -- Epoch 16
# Norm: 144011.26, NNZs: 81, Bias: -6269.135839, T: 16816, Avg. loss: 246099713.566004
# Total training time: 0.04 seconds.
# -- Epoch 17
# Norm: 143946.10, NNZs: 81, Bias: -6379.165272, T: 17867, Avg. loss: 247111928.968575
# Total training time: 0.04 seconds.
best_score_)

print("Train Score/r2: ", r2_score(y_train,X_train_preds))
print("Test Score/r2: ", r2_score(y_test,X_test_preds))

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=True)
    return au_corr[0:n]

# %%
print("Top Absolute Correlations")
print(get_top_abs_correlations(pred, 30))
# Out:
# Top Absolute Correlations
# poly_reg     paste_preg     1.019385e-16
# paste_preg   et_reg         1.836076e-16
# paste_dtree  paste_preg     2.415924e-16
# paste_preg   xgb            2.768964e-16
# knn_reg      paste_preg     3.024781e-16
# ridge_reg    paste_preg     3.690438e-16
# paste_preg   rf_reg         6.038528e-16
#              gboost         6.447018e-16
#              ada_dtree      7.264542e-16
# lasso_reg    paste_preg     7.553388e-16
# svm          paste_preg     1.110282e-15
# dtree_reg    paste_preg     1.278437e-15
# lr           paste_preg     1.446010e-15
# sgd_reg      paste_preg     1.516167e-15
# bag_dtree    paste_preg     1.544068e-15
# dtree_reg    gboost         8.659656e-01
# lr           dtree_reg      9.034119e-01
# poly_reg     dtree_reg      9.034250e-01
# lasso_reg    dtree_reg      9.043886e-01
# dtree_reg    xgb            9.073566e-01
# ridge_reg    dtree_reg      9.095783e-01
# dtree_reg    ada_dtree      9.164897e-01
# knn_reg      dtree_reg      9.188617e-01
# dtree_reg    et_reg         9.193281e-01
# knn_reg      gboost         9.211441e-01
# sgd_reg      dtree_reg      9.233879e-01
# svm          dtree_reg      9.258794e-01
# dtree_reg    paste_dtree    9.273489e-01
#              bag_dtree      9.397584e-01
#              rf_reg         9.435153e-01
# dtype: float64

# %% [markdown]
# ## Voting least co-related

# %%
#poly_reg,paste_preg,et_reg,paste_dtree,xgb


from sklearn.ensemble import VotingRegressor

voting_reg = VotingRegressor(estimators=[('xgb', xgb_reg_grid), 
                                        ('paste_preg', paste_preg_grid),
                                          ('poly_reg',reg_poly_grid),
                                         ('et_reg',et_reg_grid),
                                         ('paste_dtree',paste_dtree_grid)])
voting_reg.fit(X_train, y_train)

for reg in (xgb_reg_grid, paste_preg_grid, reg_poly_grid,et_reg_grid,paste_dtree_grid,voting_reg):
    reg.fit(X_train, y_train)
    y_pred = reg.predict(X_test)
    print(reg.__class__.__name__, r2_score(y_test, y_pred))
# Out:
# GridSearchCV 0.8667388468544738
# GridSearchCV -0.047972079350314
# GridSearchCV 0.8755530241459522
# GridSearchCV 0.8558849734642543
# GridSearchCV 0.8660251938309308
# VotingRegressor 0.8363833252204408

# %%
print('CV Score: ',voting_reg.best_score_)

print("Train Score/r2: ", r2_score(y_train,X_train_preds))
print("Test Score/r2: ", r2_score(y_test,X_test_preds))

# %% [markdown]
# ## Stacking top 5

# %%
'''
from sklearn.ensemble import StackingRegressor

streg1 = StackingRegressor(estimators=[('xgb', xgb_reg_grid), 
                                          ('svm', svm_reg_grid),
                                          ('lasso',grid_lasso),
                                         ('ridge',grid_ridge),
                                         ('sgd',grid_sgd)],
                           final_estimator=XGBRegressor(random_state=42,early_stopping_rounds=2,objective= 'reg:linear',silent=True))

streg1_param = {
             'final_estimator__max_depth' : [2,4,6],
              'final_estimator__n_estimators' : [20,40],
              'final_estimator__learning_rate' : [0.5,0.8],
                'final_estimator__subsample':[0.8,1]
             }
streg1_grid = GridSearchCV(streg1, streg1_param,cv=5, return_train_score=True, )
streg1_grid.fit(X_train,y_train)
'''
# Out:
# "\nfrom sklearn.ensemble import StackingRegressor\n\nstreg1 = StackingRegressor(estimators=[('xgb', xgb_reg_grid), \n                                          ('svm', svm_reg_grid),\n                                          ('lasso',grid_lasso),\n                                         ('ridge',grid_ridge),\n                                         ('sgd',grid_sgd)],\n                           final_estimator=XGBRegressor(random_state=42,early_stopping_rounds=2,objective= 'reg:linear',silent=True))\n\nstreg1_param = {\n             'final_estimator__max_depth' : [2,4,6],\n              'final_estimator__n_estimators' : [20,40],\n              'final_estimator__learning_rate' : [0.5,0.8],\n                'final_estimator__subsample':[0.8,1]\n             }\nstreg1_grid = GridSearchCV(streg1, streg1_param,cv=5, return_train_score=True, )\nstreg1_grid.fit(X_train,y_train)\n"

# %%
from sklearn.ensemble import StackingRegressor

streg1 = StackingRegressor(estimators=[('xgb', xgb_reg_grid), 
                                          ('svm', svm_reg_grid),
                                          ('lasso',grid_lasso),
                                         ('ridge',grid_ridge),
                                         ('sgd',grid_sgd)],
                           final_estimator=LinearRegression())

streg1_param = {}
streg1_grid = GridSearchCV(streg1, streg1_param,cv=5, return_train_score=True, )
streg1_grid.fit(X_train,y_train)
# Out:
# -- Epoch 1
# Norm: 80740.23, NNZs: 81, Bias: -491.362668, T: 840, Avg. loss: 704692158.150435
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 97129.97, NNZs: 81, Bias: -871.996686, T: 1680, Avg. loss: 431648316.488110
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 108190.92, NNZs: 81, Bias: -2194.721802, T: 2520, Avg. loss: 400564406.864861
# Total training time: 0.01 seconds.
# -- Epoch 4
# Norm: 113964.87, NNZs: 81, Bias: -2322.311200, T: 3360, Avg. loss: 382963998.277486
# Total training time: 0.01 seconds.
# -- Epoch 5
# Norm: 123814.27, NNZs: 81, Bias: -3385.324075, T: 4200, Avg. loss: 364994299.588487
# Total training time: 0.01 seconds.
# -- Epoch 6
# Norm: 128782.59, NNZs: 81, Bias: -4629.346146, T: 5040, Avg. loss: 338503885.348113
# Total training time: 0.01 seconds.
# -- Epoch 7
# Norm: 130479.39, NNZs: 81, Bias: -5051.951713, T: 5880, Avg. loss: 346168885.794428
# Total training time: 0.01 seconds.
# -- Epoch 8
# Norm: 131094.42, NNZs: 81, Bias: -5741.792333, T: 6720, Avg. loss: 268982770.456294
# Total training time: 0.01 seconds.
# -- Epoch 9
# Norm: 132497.23, NNZs: 81, Bias: -5829.690118, T: 7560, Avg. loss: 273844429.360625
# Total training time: 0.02 seconds.
# -- Epoch 10
# Norm: 133426.56, NNZs: 81, Bias: -6186.755317, T: 8400, Avg. loss: 268737307.825914
# Total training time: 0.02 seconds.
# -- Epoch 11
# Norm: 134962.36, NNZs: 81, Bias: -6223.910850, T: 9240, Avg. loss: 272651710.960126
# Total training time: 0.02 seconds.
# -- Epoch 12
# Norm: 135469.46, NNZs: 81, Bias: -6437.689901, T: 10080, Avg. loss: 270613106.290517
# Total training time: 0.02 seconds.
# -- Epoch 13
# Norm: 135860.33, NNZs: 81, Bias: -6303.380212, T: 10920, Avg. loss: 258354352.403605
# Total training time: 0.02 seconds.
# -- Epoch 14
# Norm: 135797.40, NNZs: 81, Bias: -6517.763530, T: 11760, Avg. loss: 257929911.356804
# Total training time: 0.02 seconds.
# -- Epoch 15
# Norm: 136245.45, NNZs: 81, Bias: -6359.358666, T: 12600, Avg. loss: 257472738.402666
# Total training time: 0.02 seconds.
# -- Epoch 16
# Norm:
# Total training time: 0.03 seconds.
# -- Epoch 22
# Norm: 136813.07, NNZs: 81, Bias: -2781.206546, T: 18480, Avg. loss: 273073991.918011
# Total training time: 0.04 seconds.
# -- Epoch 23
# Norm: 136821.37, NNZs: 81, Bias: -2781.481491, T: 19320, Avg. loss: 273067580.240878
# Total training time: 0.04 seconds.
# -- Epoch 24
# Norm: 136830.53, NNZs: 81, Bias: -2781.182017, T: 20160, Avg. loss: 273051410.315895
# Total training time: 0.04 seconds.
# -- Epoch 25
# Norm: 136837.54, NNZs: 81, Bias: -2782.381380, T: 21000, Avg. loss: 273051236.451669
# Total training time: 0.04 seconds.
# -- Epoch 26
# Norm: 136844.45, NNZs: 81, Bias: -2783.646369, T: 21840, Avg. loss: 273043411.367333
# Total training time: 0.04 seconds.
# -- Epoch 27
# Norm: 136845.85, NNZs: 81, Bias: -2783.893087, T: 22680, Avg. loss: 272893654.570123
# Total training time: 0.04 seconds.
# -- Epoch 28
# Norm: 136847.18, NNZs: 81, Bias: -2784.180423, T: 23520, Avg. loss: 272891849.650286
# Total training time: 0.05 seconds.
# -- Epoch 29
# Norm: 136848.60, NNZs: 81, Bias: -2784.406400, T: 24360, Avg. loss: 272890244.675545
# Total training time: 0.05 seconds.
# -- Epoch 30
# Norm: 136849.90, NNZs: 81, Bias: -2784.718488, T: 25200, Avg. loss: 272888148.971627
# Total training time: 0.05 seconds.
# -- Epoch 31
# Norm: 136851.34, NNZs: 81, Bias: -2784.931142, T: 26040, Avg. loss: 272886943.317865
# Total training time: 0.05 seconds.
# -- Epoch 32
# Norm: 136851.62, NNZs: 81, Bias: -2784.980979, T: 26880, Avg. loss: 272856784.595307
# Total training time: 0.05 seconds.
# -- Epoch 33
# Norm: 136851.90, NNZs: 81, Bias: -2785.026831, T: 27720, Avg. loss: 272856476.491418
# Total training time: 0.05 seconds.
# -- Epoch 34
# Norm: 136852.18, NNZs: 81, Bias: -2785.075105, T: 28560, Avg. loss: 272856132.005487
# Total training time: 0.06 seconds.
# -- Epoch 35
# Norm: 136852.46, NNZs: 81, Bias: -2785.120388, T: 29400, Avg. loss: 272855817.424469
# Total training time: 0.06 seconds.
# -- Epoch 36
# Norm: 136852.75, NNZs: 81, Bias: -2785.165795, T: 30240, Avg. loss: 272855492.422256
# Total training time: 0.06 seconds.
# Convergence after 36 epochs took 0.06 seconds

# %%
print(f'Best Mean Cross Validation Score is {streg1_grid.best_score_}')
print(f'Best Mean Cross Validation Score is {streg1_grid.best_params_}')
print(f'Train score is {streg1_grid.score(X_train,y_train)}')
print(f'Test score is {streg1_grid.score(X_test,y_test)}')

# %% [markdown]
# ## Stacking top un-correlated

# %%
from sklearn.ensemble import StackingClassifier

sclf1 = StackingClassifier(estimators=[('xgb', xgb_reg_grid), 
                                        ('paste_preg', paste_preg_grid),
                                          ('poly_reg',reg_poly_grid),
                                         ('et_reg',et_reg_grid),
                                         ('paste_dtree',paste_dtree_grid)], final_estimator=LinearRegression())

sclf1_param = {
              'final_estimator__C' : [0.1,0.2],
             }
sclf1_grid = GridSearchCV(sclf1, sclf1_param,cv=5, return_train_score=True, )
sclf1_grid.fit(X_train,y_train)

# %%
print(f'Best Mean Cross Validation Score is {streg1_grid.best_score_}')
print(f'Best Mean Cross Validation Score is {streg1_grid.best_params_}')
print(f'Train score is {streg1_grid.score(X_train,y_train)}')
print(f'Test score is {streg1_grid.score(X_test,y_test)}')
